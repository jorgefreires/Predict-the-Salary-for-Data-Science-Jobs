# %%
# librerias y configuración

import pandas as pd
from pycaret.regression import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
import lightgbm as lgbm
from sklearn.model_selection import GridSearchCV

# %%
# cargar datos

train = pd.read_csv('../data/train.csv')

train.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary_in_usd  \
# 0          2                 3                2         17         140250
# 1          2                 3                2         17         135000
# 2          1                 2                2          5         100000
# 3          1                 2                0         36         270000
# 4          1                 2                2         17          26005
#
#    employee_residence  remote_ratio  company_location  company_size
# 0                  47           100                41             1
# 1                  47           100                41             1
# 2                  47           100                41             1
# 3                  47           100                41             0
# 4                  40             0                41             0

# %%
# se usa pycaret para comparar los distintos modelos de regresión

reg = setup(data=train, target='salary_in_usd', session_id=1)
# Out:
# <style type="text/css">
# #T_c7273_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c7273">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7273_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c7273_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7273_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7273_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c7273_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7273_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c7273_row1_col1" class="data row1 col1" >salary_in_usd</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7273_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c7273_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7273_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c7273_row3_col1" class="data row3 col1" >(500, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7273_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c7273_row4_col1" class="data row4 col1" >(500, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7273_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c7273_row5_col1" class="data row5 col1" >(350, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7273_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c7273_row6_col1" class="data row6 col1" >(150, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7273_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c7273_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7273_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_c7273_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7273_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_c7273_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7273_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_c7273_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7273_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_c7273_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c7273_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_c7273_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c7273_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_c7273_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c7273_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_c7273_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c7273_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_c7273_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c7273_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_c7273_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c7273_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_c7273_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c7273_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c7273_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_c7273_row18_col1" class="data row18 col1" >529a</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_2172f th {
#   text-align: left;
# }
# #T_2172f_row0_col0, #T_2172f_row0_col6, #T_2172f_row1_col0, #T_2172f_row1_col1, #T_2172f_row1_col2, #T_2172f_row1_col3, #T_2172f_row1_col4, #T_2172f_row1_col5, #T_2172f_row2_col0, #T_2172f_row2_col1, #T_2172f_row2_col2, #T_2172f_row2_col3, #T_2172f_row2_col4, #T_2172f_row2_col5, #T_2172f_row2_col6, #T_2172f_row3_col0, #T_2172f_row3_col1, #T_2172f_row3_col2, #T_2172f_row3_col3, #T_2172f_row3_col4, #T_2172f_row3_col5, #T_2172f_row3_col6, #T_2172f_row4_col0, #T_2172f_row4_col1, #T_2172f_row4_col2, #T_2172f_row4_col3, #T_2172f_row4_col4, #T_2172f_row4_col5, #T_2172f_row4_col6, #T_2172f_row5_col0, #T_2172f_row5_col1, #T_2172f_row5_col2, #T_2172f_row5_col3, #T_2172f_row5_col4, #T_2172f_row5_col5, #T_2172f_row5_col6, #T_2172f_row6_col0, #T_2172f_row6_col1, #T_2172f_row6_col2, #T_2172f_row6_col3, #T_2172f_row6_col4, #T_2172f_row6_col5, #T_2172f_row6_col6, #T_2172f_row7_col0, #T_2172f_row7_col1, #T_2172f_row7_col2, #T_2172f_row7_col3, #T_2172f_row7_col4, #T_2172f_row7_col5, #T_2172f_row7_col6, #T_2172f_row8_col0, #T_2172f_row8_col1, #T_2172f_row8_col2, #T_2172f_row8_col3, #T_2172f_row8_col4, #T_2172f_row8_col5, #T_2172f_row8_col6, #T_2172f_row9_col0, #T_2172f_row9_col1, #T_2172f_row9_col2, #T_2172f_row9_col3, #T_2172f_row9_col4, #T_2172f_row9_col5, #T_2172f_row9_col6, #T_2172f_row10_col0, #T_2172f_row10_col1, #T_2172f_row10_col2, #T_2172f_row10_col3, #T_2172f_row10_col4, #T_2172f_row10_col5, #T_2172f_row10_col6, #T_2172f_row11_col0, #T_2172f_row11_col1, #T_2172f_row11_col2, #T_2172f_row11_col3, #T_2172f_row11_col4, #T_2172f_row11_col5, #T_2172f_row11_col6, #T_2172f_row12_col0, #T_2172f_row12_col1, #T_2172f_row12_col2, #T_2172f_row12_col3, #T_2172f_row12_col4, #T_2172f_row12_col5, #T_2172f_row12_col6, #T_2172f_row13_col0, #T_2172f_row13_col1, #T_2172f_row13_col2, #T_2172f_row13_col3, #T_2172f_row13_col4, #T_2172f_row13_col5, #T_2172f_row13_col6, #T_2172f_row14_col0, #T_2172f_row14_col1, #T_2172f_row14_col2, #T_2172f_row14_col3, #T_2172f_row14_col4, #T_2172f_row14_col5, #T_2172f_row14_col6, #T_2172f_row15_col0, #T_2172f_row15_col1, #T_2172f_row15_col2, #T_2172f_row15_col3, #T_2172f_row15_col4, #T_2172f_row15_col5, #T_2172f_row15_col6, #T_2172f_row16_col0, #T_2172f_row16_col1, #T_2172f_row16_col2, #T_2172f_row16_col3, #T_2172f_row16_col4, #T_2172f_row16_col5, #T_2172f_row16_col6, #T_2172f_row17_col0, #T_2172f_row17_col1, #T_2172f_row17_col2, #T_2172f_row17_col3, #T_2172f_row17_col4, #T_2172f_row17_col5, #T_2172f_row17_col6, #T_2172f_row18_col0, #T_2172f_row18_col1, #T_2172f_row18_col2, #T_2172f_row18_col3, #T_2172f_row18_col4, #T_2172f_row18_col5, #T_2172f_row18_col6 {
#   text-align: left;
# }
# #T_2172f_row0_col1, #T_2172f_row0_col2, #T_2172f_row0_col3, #T_2172f_row0_col4, #T_2172f_row0_col5, #T_2172f_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2172f_row0_col7, #T_2172f_row1_col7, #T_2172f_row2_col7, #T_2172f_row3_col7, #T_2172f_row4_col7, #T_2172f_row5_col7, #T_2172f_row6_col7, #T_2172f_row7_col7, #T_2172f_row8_col7, #T_2172f_row10_col7, #T_2172f_row11_col7, #T_2172f_row12_col7, #T_2172f_row13_col7, #T_2172f_row14_col7, #T_2172f_row15_col7, #T_2172f_row16_col7, #T_2172f_row17_col7, #T_2172f_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2172f_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2172f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2172f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2172f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2172f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2172f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2172f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2172f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_
col7" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_2172f_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_2172f_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_2172f_row5_col1" class="data row5 col1" >41318.1934</td>
#       <td id="T_2172f_row5_col2" class="data row5 col2" >3566384283.7048</td>
#       <td id="T_2172f_row5_col3" class="data row5 col3" >57967.4447</td>
#       <td id="T_2172f_row5_col4" class="data row5 col4" >0.3032</td
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]
# LGBMRegressor(random_state=1)

# %%
# de entre los 5 mejores modelos según pycaret, se cambian sus hiperparametros y se comparan sus RMSE

df = pd.read_csv("../data/train.csv")

X = df.drop("salary_in_usd", axis=1) 
y = df["salary_in_usd"] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Gradient Boosting Regressor

param_grid_gbr = {
'n_estimators': [50, 100, 150],
'max_depth': [3, 5, 7],
'learning_rate': [0.1, 0.01, 0.001]
}

gbr_grid = GridSearchCV(GradientBoostingRegressor(random_state=42), param_grid_gbr, cv=3, n_jobs=-1)
gbr_grid.fit(X_train, y_train)
y_pred_gbr = gbr_grid.predict(X_test)
rmse_gbr = mean_squared_error(y_test, y_pred_gbr, squared=False)
print("Best RMSE for Gradient Boosting Regressor:", rmse_gbr)
print("Best parameters for Gradient Boosting Regressor:", gbr_grid.best_params_)
# Out:
# Best RMSE for Gradient Boosting Regressor: 46570.50685114079
# Best parameters for Gradient Boosting Regressor: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}

# %%
# Random Forest Regressor

# %%
# Extra Trees Regressor

# %%
# Light Gradient Boosting Machine

param_grid_lgbm = {
'num_leaves': [31, 50, 100],
'learning_rate': [0.1, 0.01, 0.001],
'n_estimators': [50, 100, 150],
'max_depth': [3, 5, 7]
}

lgbm_grid = GridSearchCV(lgbm.LGBMRegressor(random_state=42), param_grid_lgbm, cv=3, n_jobs=-1)
lgbm_grid.fit(X_train, y_train)
y_pred_lgbm = lgbm_grid.predict(X_test)
rmse_lgbm = mean_squared_error(y_test, y_pred_lgbm, squared=False)
print("Best RMSE for LGBM Regressor:", rmse_lgbm)
print("Best parameters for LGBM Regressor:", lgbm_grid.best_params_)
# Out:
# Best RMSE for LGBM Regressor: 47511.86490370402
# Best parameters for LGBM Regressor: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150, 'num_leaves': 31}

# %%
# AdaBoost Regressor

# %%
# se entrena el mejor modelo (LightGBM) con todo train y se predice test

df = pd.read_csv("../data/train.csv")

X_train = df.drop("salary_in_usd", axis=1)
y_train = df["salary_in_usd"]
X_test = pd.read_csv('../data/test.csv')

params = {
'learning_rate': 0.1,
'max_depth': 5,
'n_estimators': 150,
'num_leaves': 31,
}

lgbm_model = lgbm.LGBMRegressor(**params)

lgbm_model.fit(X_train, y_train)

y_pred_lgbm = lgbm_model.predict(X_test)

muestra = pd.DataFrame()

muestra['id'] = range(len(y_pred_lgbm))
muestra['salary_in_usd'] = pd.DataFrame(y_pred_lgbm)

muestra.to_csv('../data/muestra.csv', index=False)
