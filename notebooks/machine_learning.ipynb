# %%
# librerias y configuración

import pandas as pd
from pycaret.regression import *
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import HuberRegressor, BayesianRidge, Ridge, OrthogonalMatchingPursuit

# %%
# cargar datos

train = pd.read_csv('../data/train.csv')

# %%
# se usa pycaret para comparar los distintos modelos de regresión

reg = setup(data=train, target='salary_in_usd', session_id=1)
# Out:
# <style type="text/css">
# #T_5e169_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5e169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e169_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5e169_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e169_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e169_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5e169_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e169_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5e169_row1_col1" class="data row1 col1" >salary_in_usd</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e169_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5e169_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e169_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5e169_row3_col1" class="data row3 col1" >(500, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e169_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5e169_row4_col1" class="data row4 col1" >(500, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e169_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5e169_row5_col1" class="data row5 col1" >(350, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e169_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5e169_row6_col1" class="data row6 col1" >(150, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e169_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5e169_row7_col1" class="data row7 col1" >165</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e169_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_5e169_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e169_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_5e169_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5e169_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_5e169_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5e169_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_5e169_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5e169_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_5e169_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5e169_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_5e169_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5e169_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_5e169_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5e169_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_5e169_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5e169_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_5e169_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5e169_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_5e169_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5e169_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5e169_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_5e169_row18_col1" class="data row18 col1" >84bb</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           21:27:41
# Status     . . . . . . . . . . . . . . . . . .   Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_553f2 th {
#   text-align: left;
# }
# #T_553f2_row0_col0, #T_553f2_row0_col2, #T_553f2_row0_col6, #T_553f2_row1_col0, #T_553f2_row1_col1, #T_553f2_row1_col2, #T_553f2_row1_col3, #T_553f2_row1_col4, #T_553f2_row1_col5, #T_553f2_row1_col6, #T_553f2_row2_col0, #T_553f2_row2_col1, #T_553f2_row2_col3, #T_553f2_row2_col4, #T_553f2_row2_col5, #T_553f2_row2_col6, #T_553f2_row3_col0, #T_553f2_row3_col1, #T_553f2_row3_col2, #T_553f2_row3_col3, #T_553f2_row3_col4, #T_553f2_row3_col5, #T_553f2_row3_col6, #T_553f2_row4_col0, #T_553f2_row4_col1, #T_553f2_row4_col2, #T_553f2_row4_col3, #T_553f2_row4_col4, #T_553f2_row4_col5, #T_553f2_row4_col6, #T_553f2_row5_col0, #T_553f2_row5_col1, #T_553f2_row5_col2, #T_553f2_row5_col3, #T_553f2_row5_col4, #T_553f2_row5_col5, #T_553f2_row5_col6, #T_553f2_row6_col0, #T_553f2_row6_col1, #T_553f2_row6_col2, #T_553f2_row6_col3, #T_553f2_row6_col4, #T_553f2_row6_col5, #T_553f2_row6_col6, #T_553f2_row7_col0, #T_553f2_row7_col1, #T_553f2_row7_col2, #T_553f2_row7_col3, #T_553f2_row7_col4, #T_553f2_row7_col5, #T_553f2_row7_col6, #T_553f2_row8_col0, #T_553f2_row8_col1, #T_553f2_row8_col2, #T_553f2_row8_col3, #T_553f2_row8_col4, #T_553f2_row8_col5, #T_553f2_row8_col6, #T_553f2_row9_col0, #T_553f2_row9_col1, #T_553f2_row9_col2, #T_553f2_row9_col3, #T_553f2_row9_col4, #T_553f2_row9_col5, #T_553f2_row9_col6, #T_553f2_row10_col0, #T_553f2_row10_col1, #T_553f2_row10_col2, #T_553f2_row10_col3, #T_553f2_row10_col4, #T_553f2_row10_col5, #T_553f2_row11_col0, #T_553f2_row11_col1, #T_553f2_row11_col2, #T_553f2_row11_col3, #T_553f2_row11_col4, #T_553f2_row11_col5, #T_553f2_row11_col6, #T_553f2_row12_col0, #T_553f2_row12_col1, #T_553f2_row12_col2, #T_553f2_row12_col3, #T_553f2_row12_col4, #T_553f2_row12_col5, #T_553f2_row12_col6, #T_553f2_row13_col0, #T_553f2_row13_col1, #T_553f2_row13_col2, #T_553f2_row13_col3, #T_553f2_row13_col4, #T_553f2_row13_col5, #T_553f2_row13_col6, #T_553f2_row14_col0, #T_553f2_row14_col1, #T_553f2_row14_col2, #T_553f2_row14_col3, #T_553f2_row14_col4, #T_553f2_row14_col5, #T_553f2_row14_col6, #T_553f2_row15_col0, #T_553f2_row15_col1, #T_553f2_row15_col2, #T_553f2_row15_col3, #T_553f2_row15_col4, #T_553f2_row15_col5, #T_553f2_row15_col6, #T_553f2_row16_col0, #T_553f2_row16_col1, #T_553f2_row16_col2, #T_553f2_row16_col3, #T_553f2_row16_col4, #T_553f2_row16_col5, #T_553f2_row16_col6, #T_553f2_row17_col0, #T_553f2_row17_col1, #T_553f2_row17_col2, #T_553f2_row17_col3, #T_553f2_row17_col4, #T_553f2_row17_col5, #T_553f2_row17_col6 {
#   text-align: left;
# }
# #T_553f2_row0_col1, #T_553f2_row0_col3, #T_553f2_row0_col4, #T_553f2_row0_col5, #T_553f2_row2_col2, #T_553f2_row10_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_553f2_row0_col7, #T_553f2_row1_col7, #T_553f2_row2_col7, #T_553f2_row3_col7, #T_553f2_row4_col7, #T_553f2_row5_col7, #T_553f2_row6_col7, #T_553f2_row7_col7, #T_553f2_row8_col7, #T_553f2_row9_col7, #T_553f2_row10_col7, #T_553f2_row11_col7, #T_553f2_row12_col7, #T_553f2_row13_col7, #T_553f2_row14_col7, #T_553f2_row16_col7, #T_553f2_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_553f2_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_553f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_553f2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_553f2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_553f2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_553f2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_553f2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_553f2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_553f2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_553f2_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_553f2_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_553f2_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_553f2_row0_col1" class="data row0 col1" >32056.4260</td>
#       <td id="T_553f2_row0_col2" class="data row0 col2" >2550248006.1688</td>
#       <td id="T_553f2_row0_col3" class="data row0 col3" >48344.1074</td>
#       <td id="T_553f2_row0_col4" class="data row0 col4" >0.5165</td>
#       <td id="T_553f2_row0_col5" class="data row0 col5" >0.4722</td>
#       <td id="T_553f2_row0_col6" class="data row0 col6" >0.4477</td>
#       <td id="T_553f2_row0_col7" class="data row0 col7" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_553f2_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_553f2_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_553f2_row1_col1" class="data row1 col1" >32618.3871</td>
#       <td id="T_553f2_row1_col2" class="data row1 col2" >2592625167.5851</td>
#       <td id="T_553f2_row1_col3" class="data row1 col3" >48589.6280</td>
#       <td id="T_553f2_row1_col4" class="data row1 col4" >0.5130</td>
#       <td id="T_553f2_row1_col5" class="data row1 col5" >0.4813</td>
#       <td id="T_553f2_row1_col6" class="data row1 col6" >0.4596</td>
#       <td id="T_553f2_row1_col7" class="data row1 col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_553f2_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_553f2_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_553f2_row2_col1" class="data row2 col1" >33653.6982</td>
#       <td id="T_553f2_row2_col2" class="data row2 col2" >2512855895.7980</td>
#       <td id="T_553f2_row2_col3" class="data row2 col3" >48513.5857</td>
#       <td id="T_553f2_row2_col4" class="data row2 col4" >0.5114</td>
#       <td id="T_553f2_row2_col5" class="data row2 col5" >0.4995</td>
#       <td id="T_553f2_row2_col6" class="data row2 col6" >0.5071</td>
#       <td id="T_553f2_row2_col7" class="data row2 col7" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_553f2_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_553f2_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_553f2_row3_col1" class="data row3 col1" >34356.0714</td>
#       <td id="T_553f2_row3_col2" class="data row3 col2" >2589983966.8475</td>
#       <td id="T_553f2_row3_col3" class="data row3 col3" >49328.8218</td>
#       <td id="T_553f2_row3_col4" class="data row3 col4" >0.4945</td>
#       <td id="T_553f2_row3_col5" class="data row3 col5" >0.5305</td>
#       <td id="T_553f2_row3_col6" class="data row3 col6" >0.5264</td>
#       <td id="T_553f2_row3_col7" class="data row3 col7" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_553f2_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_553f2_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_553f2_row4_col1" class="data row4 col1" >34608.4644</td>
#       <td id="T_553f2_row4_col2" class="data row4 col2" >2604060257.1004</td>
#       <td id="T_553f2_row4_col3" class="data row4 col3" >49515.2999</td>
#       <td id="T_553f2_row4_col4" class="data row4 col4" >0.4879</td>
#       <td id="T_553f2_row4_col5" class="data row4 col5" >0.5192</td>
#       <td id="T_553f2_row4_col6" class="data row4 col6" >0.5130</td>
#       <td id="T_553f2_row4_col7" class="data row4 col7" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_553f2_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_553f2_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_553f2_row5_col1" class="data row5 col1" >33804.6728</td>
#       <td id="T_553f2_row5_col2" class="data row5 col2" >2788763122.1167</td>
#       <td id="T_553f2_row5_col3" class="data row5 col3" >50653.5264</td>
#       <td id="T_553f2_row5_col4" class="data row5 col4" >0.4661</td>
#       <td id="T_553f2_row5_col5" class="data row5 col5" >0.4943</td>
#       <td id="T_553f2_row5_col6" class="data row5 col6" >0.4736</td>
#       <td id="T_553f2_row5_col7" clas
# HuberRegressor()

# %%
# de entre los 5 mejores modelos según pycaret, se cambian sus hiperparametros y se comparan sus RMSE

df = pd.read_csv("../data/train.csv")

X = df.drop("salary_in_usd", axis=1) 
y = df["salary_in_usd"] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
# Huber Regressor

param_grid_hr = {
    'epsilon': [1.35, 1.5, 1.75],
    'alpha': [0.0001, 0.001, 0.01]
}

hr_grid = GridSearchCV(HuberRegressor(), param_grid_hr, cv=3, n_jobs=-1)
hr_grid.fit(X_train, y_train)
y_pred_hr = hr_grid.predict(X_test)
rmse_hr = mean_squared_error(y_test, y_pred_hr, squared=False)
print("Best RMSE for Huber Regressor:", rmse_hr)
print("Best parameters for Huber Regressor:", hr_grid.best_params_)
# Out:
# Best RMSE for Huber Regressor: 43746.017800068905
# Best parameters for Huber Regressor: {'alpha': 0.0001, 'epsilon': 1.75}

# %%
# Gradient Boosting Regressor

param_grid_gbr = {
'n_estimators': [50, 100, 150],
'max_depth': [3, 5, 7],
'learning_rate': [0.1, 0.01, 0.001]
}

gbr_grid = GridSearchCV(GradientBoostingRegressor(random_state=42), param_grid_gbr, cv=3, n_jobs=-1)
gbr_grid.fit(X_train, y_train)
y_pred_gbr = gbr_grid.predict(X_test)
rmse_gbr = mean_squared_error(y_test, y_pred_gbr, squared=False)
print("Best RMSE for Gradient Boosting Regressor:", rmse_gbr)
print("Best parameters for Gradient Boosting Regressor:", gbr_grid.best_params_)
# Out:
# Best RMSE for Gradient Boosting Regressor: 43958.950400169655
# Best parameters for Gradient Boosting Regressor: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 150}

# %%
# Bayesian ridge

param_grid_br = {
    'alpha_1': [1e-7, 1e-6, 1e-5],
    'alpha_2': [1e-7, 1e-6, 1e-5],
    'lambda_1': [1e-7, 1e-6, 1e-5],
    'lambda_2': [1e-7, 1e-6, 1e-5],
}


br = BayesianRidge()
br_grid = GridSearchCV(br, param_grid_br, cv=3, n_jobs=-1)
br_grid.fit(X_train, y_train)
y_pred_br = br_grid.predict(X_test)
rmse_br = mean_squared_error(y_test, y_pred_br, squared=False)
print("Best RMSE for Bayesian Ridge:", rmse_br)
print("Best parameters for Bayesian Ridge:", br_grid.best_params_)
# Out:
# Best RMSE for Bayesian Ridge: 46827.6094342724
# Best parameters for Bayesian Ridge: {'alpha_1': 1e-07, 'alpha_2': 1e-07, 'lambda_1': 1e-06, 'lambda_2': 1e-05}

# %%
# Ridge Regression

param_grid_rr = {
    'alpha': [0.1, 1, 10],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
    'max_iter': [100, 500, 1000],
}

rr = Ridge(random_state=42)
rr_grid = GridSearchCV(rr, param_grid_rr, cv=3, n_jobs=-1)
rr_grid.fit(X_train, y_train)
y_pred_rr = rr_grid.predict(X_test)
rmse_rr = mean_squared_error(y_test, y_pred_rr, squared=False)
print("Best RMSE for Ridge Regression:", rmse_rr)
print("Best parameters for Ridge Regression:", rr_grid.best_params_)
# Out:
# Best RMSE for Ridge Regression: 45873.02566418878
# Best parameters for Ridge Regression: {'alpha': 10, 'max_iter': 100, 'solver': 'sag'}

# %%
# Orthogonal Matching Pursuit

param_grid_omp = {
    'n_nonzero_coefs': [5, 10, 15],
    'fit_intercept': [True, False],
    'normalize': [True, False]
}

omp_grid = GridSearchCV(OrthogonalMatchingPursuit(), param_grid_omp, cv=3, n_jobs=-1)
omp_grid.fit(X_train, y_train)
y_pred_omp = omp_grid.predict(X_test)
rmse_omp = mean_squared_error(y_test, y_pred_omp, squared=False)
print("Best RMSE for Orthogonal Matching Pursuit:", rmse_omp)
print("Best parameters for Orthogonal Matching Pursuit:", omp_grid.best_params_)
# Out:
# Best RMSE for Orthogonal Matching Pursuit: 45614.654753841736
# Best parameters for Orthogonal Matching Pursuit: {'fit_intercept': True, 'n_nonzero_coefs': 10, 'normalize': False}

# %%
# se juega con los parámetros del mejor modelo (Huber Regressor) para ajustarlos al máximo

hr_model = HuberRegressor(epsilon=1.54, alpha=0.0001, fit_intercept=True)
hr_model.fit(X_train, y_train)
y_pred_hr = hr_model.predict(X_test)
rmse_hr = mean_squared_error(y_test, y_pred_hr, squared=False)
print("Best RMSE for Huber Regressor:", rmse_hr)
# Out:
# Best RMSE for Huber Regressor: 43436.89388992864

# %%
# se entrena el dicho modelo con todo train y se predice test

# cargamos los datos
df = pd.read_csv("../data/train.csv")

# separamos las características y las etiquetas
X_train = df.drop("salary_in_usd", axis=1)
y_train = df["salary_in_usd"]
X_test = pd.read_csv('../data/test.csv')

# definimos el modelo y sus parámetros
hr_model2 = HuberRegressor(epsilon=1.54, alpha=0.0001, fit_intercept=True)

# entrenamos el modelo
hr_model2.fit(X_train, y_train)

# hacemos predicciones
y_pred_hr2 = hr_model2.predict(X_test)

# creamos un archivo de muestra con las predicciones
muestra = pd.DataFrame()
muestra['id'] = range(len(y_pred_hr2))
muestra['salary_in_usd'] = pd.DataFrame(y_pred_hr2)
muestra.to_csv('../data/muestra.csv', index=False)
